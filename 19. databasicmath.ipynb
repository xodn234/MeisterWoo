# %% [markdown]
# # 8.7 베타분포, 감마분포, 디리클레분포

# %% [markdown]
# # 베타분포
#
# - 베타분포는 a 와  b라는 두 모수를 가지며 표본 공간은 0과 1사이의 실수다.

# %% [markdown]
# # 베타분포와 베이지안 추정
#
# - 베타분포는 0부터 1까지의 값을가질 수 있는 베르누이분포의 무스 u의 값을 베이지안 추정한 결과를 표현한 것이다.
#   베이지안 추정은 모수가 가질 수 있는 모든 값에 대해 가능성을 확률뷴포로 나타낸 것을 말한다.

# %% [markdown]
# # 감마분포
#
# - 감마분포도 베타분포처럼 모수의 베이지안 춪어에 사용된다. 다만 베타분포가 0부터 1사잇값을 가지는 모수를 베이지안 방법으로   추정하는 데 사용되는 것과 달리 감마분포는 0부터 무한대의 값을 가지는 양수 값을 추정하는데 사용된다.

# %% [markdown]
# # 디리클레분포
#
# - 디리클레분포는 베타분포의 확장판이라고 할 수 있다. 베타분포는 0과 1사이의 값을 가지는 단일 확률변수의 베이지안 모형에     사용되고 디리클레분포는 0과 1사이의 값을 가지는 다변수 확률변수의 베이지안 모형에 사용된다.

# %% [markdown]
# # 9.1 확률분포의 추정
#
# - '분석하고자 하는 데이터가 어떤 확률변수로부터 실현된 표본이다' 는 데이터분석의 첫번째 가정이다

# %% [markdown]
# # 모수추정방법론

# %% [markdown]
# # 9.2 최대가능도 추정법

# %% [markdown]
# # 가능도함수

# %% [markdown]
# # 최대가능도 추정법

# %% [markdown]
# # 로그가능도함수

# %% [markdown]
# # 베르누이분포의 최대가능도 모수 측정

# %% [markdown]
# # 정규분포의 최대가능도 모수 측정

# %% [markdown]
# # 다변수정규뷴포의 최대가능도 무수 추정

# %% [markdown]
# # 9.3 베이즈 추정법
#
# - 베이즈 추정법은 모숫값이 가질 수 있는 모든 가능성의 분포를 계산하는 작업이다.

# %% [markdown]
# # 베이즈 추정법의 기본 원리
#
# - 모수적 방법 : 다른 확률분포를 사용하여 추정된 모수의 분포를 나타낸다
# - 비모수적 방법 : 모수의 분포와 도일한 분포를 가지는 실제 표본 집합을 생성하여 히스토그램이나 최빈값 등으로 분포를 표현한다.

# %% [markdown]
# # 베르누의분포의 모수 측정
