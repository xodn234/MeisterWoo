# %%
# Integer 객체

class Integer:
    def __init__(self, number):
        self.number = number
        
    def __add__(self, obj):
        return self.number + obj.number
    
    def __str__(self):
        return str(self.number)
    
    def __repr__(self):
        return str(self.number)

# %%
num1 = Integer(1)
num2 = Integer(2)

# %%
num1 + num2
# Out:
# 3

# %%
num1
# Out:
# 1

# %%
print(num1)
# Out:
# 1

# %%
# 계좌(Account) 클래스 만들기 
# 변수 : 자산(asset), 이자율(interest)
# 함수 : 인출(drew), 입금(insert), 이자추가(add_interest)
# 인출시 자산이상의 돈을 인출할수 없습니다.

# %%
class Account:
    def __init__(self, asset=0, interest=1.05):
        self.asset = asset
        self.interest = interest
    
    def draw(self, money):
        if self.asset >= money:
            self.asset -= money
            print("{}원이 인출되었습니다.".format(money))
        else:
            print("인출금이 {}월 부족합니다.".format(money-self.asset))
    
    def insert(self, money):
        self.asset += money
        print("{}원이 인출되었습니다.".format(money))
    
    def add_interest(self):
        self.asset *= self.interest
        print("이자가 지급되었습니다.")
        pass
    
    def __repr__(self):
        return "Account(asset:{}, interest:{})".format(self.asset, self.interest)

# %%
account1 = Account(10000)

# %%
account1.asset, account1.interest
# Out:
# (10000, 1.05)

# %%
account1
# Out:
# Account(asset:10000, interest:1.05)

# %%
account1.draw(12000)
# Out:
# 인출금이 2000월 부족합니다.

# %%
account1.draw(3000)
# Out:
# 3000원이 인출되었습니다.

# %%
account1
# Out:
# Account(asset:7000, interest:1.05)

# %%
account1.add_interest()
# Out:
# 이자가 지급되었습니다.

# %%
account1
# Out:
# Account(asset:7350.0, interest:1.05)

# %%
# Module Package
- 모듈 : 변수, 함수, 클래스를 모아놓은 (.py) 확장자를 가진 파일
- 패키지 : 모듈의 기능을 디렉토리별로 정리해 놓은 개념

# %%
# 모듈 
- 파일 생성
- 모듈 호출

# %%
# %%writefile dsss.py

num = 1234

def disp1(msg):
    print("disp1", msg)
    
def disp2(msg):
    print("disp2", msg)

class Calc:
    def plus(self, *args):
        return sum(args)
# Out:
# Overwriting dsss.py

# %%
# !ls
# Out:
# 1. Jupynew.ipynb                5. pythonbasic.ipynb
# 101. tenser, keras start!.ipynb __pycache__
# 2. pythonbasic.ipynb            dss.py
# 3. pythonbasic.ipynb            dsss.py
# 4. pythonbasic.ipynb

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?
# Nothing done.

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# calc       Calc      <dss.Calc object at 0x7ff7c5015a20>
# dss        module    <module 'dss' from '/Users/itaeu/jupy/dss.py'>

# %%
# 모듈 호출 : import
import dsss

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# calc       Calc      <dss.Calc object at 0x7ff7c5015a20>
# dss        module    <module 'dss' from '/Users/itaeu/jupy/dss.py'>
# dsss       module    <module 'dsss' from '/Users/itaeu/jupy/dsss.py'>

# %%
dsss.num
# Out:
# 1234

# %%
dsss.disp1("python")
# Out:
# disp1 python

# %%
calc = dsss.Calc()

# %%
calc.plus(1, 2, 3, 4)
# Out:
# 10

# %%
# 모듈안에 특정 함수, 변수, 클래스 호출

# %%
from dsss import num, disp2

# %%
# %whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# calc       Calc        <dsss.Calc object at 0x7ff7c46b4128>
# disp2      function    <function disp2 at 0x7ff7c5003598>
# dss        module      <module 'dss' from '/Users/itaeu/jupy/dss.py'>
# dsss       module      <module 'dsss' from '/Users/itaeu/jupy/dsss.py'>
# num        int         1234

# %%
dsss.num
# Out:
# 1234

# %%
num
# Out:
# 1234

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# 모듈의 모든 변수를 가져옴
from dsss import *

# %%
# %whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# Calc       type        <class 'dsss.Calc'>
# disp1      function    <function disp1 at 0x7ff7c5003c80>
# disp2      function    <function disp2 at 0x7ff7c5003598>
# num        int         1234

# %%
# Package
- 패키지 생성
- 패키지 호출
- setup.py 패키지 설치 파일 만들기

# %%
# 디렉토리 생성

# !mkdir -p school/dsss

# %%
# !mkdir -p school/web

# %%
- tree 설치(mac)
    - 홈브루(osx 패키지 설치 관리툴) 설치
    - brew install tree

# %%
# !tree school
# Out:
# school
# ├── dsss
# └── web
#
# 2 directories, 0 files

# %%
# 패키지 사용시 디렉토리에 __init__.py 파일을 추가
# python 3.3 버전 이상에서는 필요 없음 (하위버전 호환시 써줌)

# %%
# !touch school/dsss/__init__.py
# !touch school/web/__init__.py

# %%
! tree school/
# Out:
# school/
# ├── dsss
# │   └── __init__.py
# └── web
#     └── __init__.py
#
# 2 directories, 2 files
