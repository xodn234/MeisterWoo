# %% [markdown]
# # Pandas Pivot
# - 데이터 프레임의 컬럼 데이터에서 index, coiumn, value를 선택해서 데이터 프레임을 만드는 방법
#     - 'df.pivot(index, coiumns, values)' : groupby 하고 pivot을 실행
# - df.ppivot_table(values, index, columns, aggfunc)

# %%
# pandas io
- 데이터 프레임을 저장, 로드

# %%
# load
titanic = pd.read_csv("datas/train.csv")
titanic.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
# save
titanic.to_csv("datas/titanic.csv", sep="\t", index=False)

# %%
# load : encoding
df = pd.read_csv("datas/2014_p.csv", encoding="euc-kr")
df.tail(2)
# Out:
#           ID RCTRCK     RACE_DE  RACE_NO  PARTCPT_NO  RANK RCHOSE_NM HRSMN  \
# 27216  27217     제주  2014-11-29        9           7   6.0      미주여행   김경휴
# 27217  27218     제주  2014-11-29        9           6   1.0       철옹성   장우성
#
#            RCORD ARVL_DFFRNC EACH_SCTN_PASAGE_RANK  A_WIN_SYTM_EXPECT_ALOT  \
# 27216  0:01:31.1          13   2 -  -  - 2 - 3 - 6                     6.2
# 27217  0:01:26.6         NaN   1 -  -  - 1 - 1 - 1                     3.9
#
#        WIN_STA_EXPECT_ALOT
# 27216                  9.4
# 27217                  2.9

# %%
# kaggle
- 데이터 분석, 모델을 경쟁할수 있도록 만든 서비스

# %%
# 1. 성별, 좌석등급에 따른 데이터의 수

# %%
# group by
df1 = titanic.groupby(["Sex", "Pclass"]).size().reset_index(name="Counts")
df1
# Out:
#       Sex  Pclass  Counts
# 0  female       1      94
# 1  female       2      76
# 2  female       3     144
# 3    male       1     122
# 4    male       2     108
# 5    male       3     347

# %%
# pivot
result = df1.pivot("Sex", "Pclass", "Counts")
result
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %%
# pivot table 이용
titanic["Counts"] = 1
titanic.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked  count  Count  Counts
# 889      0  111369  30.00  C148        C      1      1       1
# 890      0  370376   7.75   NaN        Q      1      1       1

# %%
result = titanic.pivot_table("Counts", ["Pclass"], ["Survived"], aggfunc=np.sum)
result
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
result["total"] = result[0] + result[1]
result
# Out:
# Survived    0    1  total
# Pclass
# 1          80  136    216
# 2          97   87    184
# 3         372  119    491

# %%
result.loc["total"] = result.loc[1] + result.loc[2] + result.loc[3]
result
# Out:
# Survived    0    1  total
# Pclass
# 1          80  136    216
# 2          97   87    184
# 3         372  119    491
# total     549  342    891
